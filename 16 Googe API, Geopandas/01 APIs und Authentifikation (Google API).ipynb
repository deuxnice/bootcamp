# %% [markdown]
# # APIs und Authentifikation (Google API)

# %% [markdown]
# Wir haben uns vor langer, langer Zeit die Erdbeben-Applikation angeschaut. Die Nutzung ist zwar begrenzt, doch es für deren Nutzung keine weitere Zulassung notwendig. Das ist bei den meisten anderen APIs nicht der Fall. In der Regel verlangen die Besitzer einer API Authentifikation der Nutzer. So können sie kontrollieren, wer wieviel nutzt. Denn auch eine API-Abfrage beansprucht Rechenkraft. Bei Millionen Abfragen kann das schnell ins Geld gehen. Es gibt dabei verschiedene API-Typen: REST, SOAP, XML-RCP oder JSON-RPC. Was die verschiedenen Vorteile dieser API-Technologien sind, schlägt ihr am besten nach. Die gängigsten sind heute REST und SOAP. Die trifft man immer wieder.

# %% [markdown]
# Wie man sich authentifiziert, wollen wir uns nun gemeinsam anschauen. Wir tun das mit der Google Maps API. Zu allererst müssen wir eine Key kreieren. Dafür brauchen wir eine Gmail-Konto und eine Kreditkarte. Wir werden keinen Rappen ausgeben, die erste 100'000 Aufrufe sind gratis. Die Kreditkarte ist trotzdem nötig. Als erstes besuchen wir [also die Google-Maps-Plattform](https://cloud.google.com/maps-platform).

# %% [markdown]
# ## Die Google API
# Die API kann man für verschiedene Sachen verwenden: Um Distanzen zu berechnen, um Standorte mit Geo-Daten auszustatten, oder um Standorte zu suchen. Natürlich nicht einzelne Standorte, sondern ganz viele. In diesem Beispiel werden wir uns bestimmte Standorte suchen.

# %% [markdown]
# Nachdem ihr Euch oben bei Google angemeldet habt, müsst ihr eine API Key generieren und abspeichern. Nun gehen wir nur Places API und Places Search. Das [ist hier](https://developers.google.com/places/web-service/intro).

# %% [markdown]
# Um Eure API keys zu finden, geht ihr zu API & Services, Credentials. [Hier](https://console.cloud.google.com/apis/credentials?project=clear-canyon-166711)

# %% [markdown]
# ### Das italienische Restaurant mit den meisten Sternen bei Google Maps?

# %% [markdown]
# Wir werden mir der Textsearch-Option arbeiten: ```https://maps.googleapis.com/maps/api/place/textsearch/output?parameters```. Wir geben ein:
# - https://maps.googleapis.com/maps/api/place/textsearch/json
# - query=italienische+restaurants+in+zurich
# - fields=formatted_address,name,rating,opening_hours,pagetoken
# - key=XXXXXX

# %%
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"
query = "query=italienische+restaurants+in+zurich&"
fields = "fields=formatted_address,name,rating,opening_hours,pagetoken&"
locationbias = "locationbias=point:lat,lng&"
key = "key=AIzaSyB3UalQQH44hO-oFA-xUZ0OwmCn22N52V8" #Diesen Schlüssel habe ich aus Google Places API

# %%
api_query = url+query+fields+locationbias+key

# %%
api_query
# Out:
# 'https://maps.googleapis.com/maps/api/place/textsearch/json?query=italienische+restaurants+in+zurich&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyB3UalQQH44hO-oFA-xUZ0OwmCn22N52V8'

# %% [markdown]
# importieren wir requests

# %%
import requests

# %%
r = requests.get(api_query)
result = r.json()

# %%
len(result)
# Out:
# 4

# %%
for key in result:
    print(key)
# Out:
# html_attributions
# next_page_token
# results
# status

# %%
result['results'][0]['geometry']['location']
# Out:
# {'lat': 47.3701154, 'lng': 8.5402376}

# %%
result['results'][0]['name']
# Out:
# 'Orsini'

# %%
len(result['results'])
# Out:
# 20

# %%
new_lst = []

for beiz in result['results']:
    address = beiz['formatted_address']
    name = beiz['name']
    rating = beiz['rating']
    lat = beiz['geometry']['location']['lat']
    long = beiz['geometry']['location']['lng']
    
    mini_dict = {'Addresse': address, 
                 'Name': name,
                 'Rating': rating,
                 'Lat':lat,
                 'Lng':long}
    
    new_lst.append(mini_dict)

# %%
import pandas as pd

# %%
pd.DataFrame(new_lst)
# Out:
#                                              Addresse        Lat       Lng  \
# 0   Am Münsterhof, Waaggasse 7, 8001 Zürich, Switz...  47.370115  8.540238
# 1             Limmatquai 82, 8001 Zürich, Switzerland  47.373517  8.543035
# 2      Niederdorfstrasse 80, 8001 Zürich, Switzerland  47.376028  8.544154
# 3         Rotwandstrasse 49, 8004 Zürich, Switzerland  47.375514  8.528423
# 4          Forchstrasse 168, 8032 Zürich, Switzerland  47.360204  8.565730
# 5               In Gassen 6, 8001 Zürich, Switzerland  47.370705  8.540779
# 6        Augustinergasse 25, 8001 Zürich, Switzerland  47.372218  8.538797
# 7         Gertrudstrasse 37, 8003 Zürich, Switzerland  47.373396  8.515301
# 8           Hohlstrasse 449, 8048 Zürich, Switzerland  47.386940  8.501478
# 9        Badenerstrasse 275, 8003 Zürich, Switzerland  47.376137  8.514691
# 10          Rudolfstrasse 6, 8008 Zürich, Switzerland  47.357036  8.557500
# 11          Nordstrasse 182, 8037 Zürich, Switzerland  47.392419  8.531426
# 12        Lavaterstrasse 87, 8002 Zürich, Switzerland  47.360255  8.533304
# 13            Ohmstrasse 11, 8050 Zürich, Switzerland  47.410185  8.545875
# 14      Niederdorfstrasse 7, 8001 Zürich, Switzerland  47.373008  8.543581
# 15       Badenerstrasse 526, 8048 Zürich, Switzerland  47.382678  8.501130
# 16          Hohlstrasse 451, 8048 Zürich, Switzerland  47.387082  8.500953
# 17            Spitalgasse 5, 8001 Zürich, Switzerland  47.373649  8.544296
# 18          Dufourstrasse 1, 8008 Zürich, Switzerland  47.364525  8.547443
# 19          Löwenstrasse 61, 8001 Zürich, Switzerland  47.376964  8.538000
#
#                      Name  Rating
# 0                  Orsini     4.6
# 1                 Bianchi     4.4
# 2                La Pasta     4.4
# 3   L'Osteria Mamma Leone     4.4
# 4              Marcellino     4.8
# 5                Bindella     4.3
# 6     Cantinetta Antinori     4.3
# 7         Da Michelangelo     4.5
# 8               Da Angela     4.6
# 9       Taverne da Angelo     4.4
# 10                Gandria     4.9
# 11           Tre Fratelli     4.5
# 12             Il Tartufo     4.3
# 13               Concerto     4.2
# 14                Pulcino     3.9
# 15                Da Cono     3.9
# 16                Azzurro     4.5
# 17   Cicchetteria Da Rosa     4.5
# 18                  Conti     4.3
# 19                  Spiga     4.1

# %% [markdown]
# Aber, das sind nur 20. Wir wollen mehr. Dafür müssen wir mit diesem Nexttoken arbeiten.

# %%
import time

# %%
new_list = []

url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"
query = "query=italienische+restaurants+in+zurich&"
fields = "fields=formatted_address,name,rating,opening_hours,pagetoken&"
locationbias = "locationbias=point:lat,lng&"
key = "key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&"
pagetoken = ''

result = range(4)
while len(result) > 3: 
    
    print(len(result))

    api_query = url+query+fields+locationbias+key+pagetoken
    print(api_query)
    time.sleep(2)
    r = requests.get(api_query)
    result = r.json()
    
    for elem in result['results']:
        address = elem['formatted_address']
        name = elem['name']
        rating = elem['rating']
        lat = elem['geometry']['location']['lat']
        long = elem['geometry']['location']['lng']
    
        mini_dict = {'Addresse': address, 
                     'Name': name,
                     'Rating': rating,
                     'Lat':lat,
                     'Lng':long}
    
        new_list.append(mini_dict)
        
    
    if len(result) > 3:
        pagetoken = 'pagetoken='+result['next_page_token'] 
    else:
        break
# Out:
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=italienische+restaurants+in+zurich&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=italienische+restaurants+in+zurich&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&pagetoken=CuQD
# %%
pd.DataFrame(new_list)
# Out:
#                                              Addresse        Lat       Lng  \
# 0   Am Münsterhof, Waaggasse 7, 8001 Zürich, Switz...  47.370115  8.540238
# 1             Limmatquai 82, 8001 Zürich, Switzerland  47.373517  8.543035
# 2      Niederdorfstrasse 80, 8001 Zürich, Switzerland  47.376028  8.544154
# 3         Rotwandstrasse 49, 8004 Zürich, Switzerland  47.375514  8.528423
# 4          Forchstrasse 168, 8032 Zürich, Switzerland  47.360204  8.565730
# 5               In Gassen 6, 8001 Zürich, Switzerland  47.370705  8.540779
# 6        Augustinergasse 25, 8001 Zürich, Switzerland  47.372218  8.538797
# 7         Gertrudstrasse 37, 8003 Zürich, Switzerland  47.373396  8.515301
# 8           Hohlstrasse 449, 8048 Zürich, Switzerland  47.386940  8.501478
# 9        Badenerstrasse 275, 8003 Zürich, Switzerland  47.376137  8.514691
# 10          Rudolfstrasse 6, 8008 Zürich, Switzerland  47.357036  8.557500
# 11          Nordstrasse 182, 8037 Zürich, Switzerland  47.392419  8.531426
# 12        Lavaterstrasse 87, 8002 Zürich, Switzerland  47.360255  8.533304
# 13            Ohmstrasse 11, 8050 Zürich, Switzerland  47.410185  8.545875
# 14      Niederdorfstrasse 7, 8001 Zürich, Switzerland  47.373008  8.543581
# 15       Badenerstrasse 526, 8048 Zürich, Switzerland  47.382678  8.501130
# 16          Hohlstrasse 451, 8048 Zürich, Switzerland  47.387082  8.500953
# 17            Spitalgasse 5, 8001 Zürich, Switzerland  47.373649  8.544296
# 18          Dufourstrasse 1, 8008 Zürich, Switzerland  47.364525  8.547443
# 19          Löwenstrasse 61, 8001 Zürich, Switzerland  47.376964  8.538000
# 20         Mainaustrasse 23, 8008 Zürich, Switzerland  47.360691  8.549923
# 21         Luisenstrasse 40, 8005 Zürich, Switzerland  47.384228  8.530403
# 22            Waaggasse 5/7, 8001 Zürich, Switzerland  47.370103  8.539889
# 23    Waffenplatzstrasse 15, 8002 Zürich, Switzerland  47.361196  8.526721
# 24       Zeughausstrasse 61, 8004 Zürich, Switzerland  47.376371  8.529278
# 25          Weberstrasse 14, 8004 Zürich, Switzerland  47.370916  8.528328
# 26           Asylstrasse 81, 8032 Zürich, Switzerland  47.366809  8.561675
# 27        Sternenstrasse 11, 8002 Zürich, Switzerland  47.360042  8.534011
# 28          Langstrasse 215, 8005 Zürich, Switzerland  47.383264  8.530178
# 29        Dufourstrasse 161, 8008 Zürich, Switzerland  47.354960  8.554980
# 30     Niederdorfstrasse 33, 8001 Zürich, Switzerland  47.374671  8.543708
# 31    Stauffacherstrasse 31, 8004 Zürich, Switzerland  47.373510  8.528681
# 32          Nansenstrasse 9, 8050 Zürich, Switzerland  47.410710  8.544784
# 33          Albisstrasse 25, 8038 Zürich, Switzerland  47.344002  8.531876
# 34    Stampfenbachstrasse 8, 8001 Zürich, Switzerland  47.377759  8.543813
# 35         Brauerstrasse 87, 8004 Zürich, Switzerland  47.379263  8.524119
# 36       Mühlebachstrasse 2, 8008 Zürich, Switzerland  47.365932  8.548957
# 37       Bellerivestrasse 2, 8008 Zürich, Switzerland  47.360935  8.547990
# 38           Forchstrasse 2, 8008 Zürich, Switzerland  47.364373  8.554729
# 39     Niederdorfstrasse 15, 8001 Zürich, Switzerland  47.373503  8.543578
# 40      Seegartenstrasse 14, 8008 Zürich, Switzerland  47.361391  8.549390
# 41       Seefeldstrasse 124, 8008 Zürich, Switzerland  47.358048  8.553901
# 42     Limmattalstrasse 228, 8049 Zürich, Switzerland  47.402282  8.495141
# 43       Seefeldstrasse 273, 8008 Zürich, Switzerland  47.348897  8.563325
# 44       Zentralstrasse 161, 8003 Zürich, Switzerland  47.375878  8.514155
# 45            Sandstrasse 7, 8003 Zürich, Switzerland  47.366224  8.521244
# 46    Stampfenbachstrasse 6, 8001 Zürich, Switzerland  47.377503  8.543925
# 47      Kasernenstrasse 77A, 8004 Zürich, Switzerland  47.376087  8.533836
# 48          Bertastrasse 36, 8003 Zürich, Switzerland  47.374101  8.513545
# 49          Hardstrasse 324, 8005 Zürich, Switzerland  47.390332  8.522853
# 50   Stampfenbachstrasse 38, 8006 Zürich, Switzerland  47.379845  8.543391
# 51            Seestrasse 82, 8002 Zürich, Switzerland  47.359684  8.531861
# 52            Schmidgasse 3, 8001 Zürich, Switzerland  47.374754  8.543548
# 53       Kanzleistrasse 103, 8004 Zürich, Switzerland  47.376152  8.522207
# 54   Mutschellenstrasse 137, 8038 Zürich, Switzerland  47.346956  8.528694
# 55     18, Giessereistrasse, 8005 Zürich, Switzerland  47.390039  8.517927
# 56       Fröhlichstrasse 37, 8008 Zürich, Switzerland  47.354557  8.556048
# 57         Freiestrasse 213, 8032 Zürich, Switzerland  47.360868  8.566563
# 58          Löwenstrasse 64, 8001 Zürich, Switzerland  47.376881  8.538433
# 59          Cramerstrasse 8, 8004 Zürich, Switzerland  47.373227  8.526123
#
#                                        Name  Rating
# 0                                    Orsini     4.6
# 1                                   Bianchi     4.4
# 2                                  La Pasta     4.4
# 3                     L'Osteria Mamma Leone     4.4
# 4                                Marcellino     4.8
# 5                                  Bindella     4.3
# 6                       Cantinetta Antinori     4.3
# 7                           Da Michelangelo     4.5
# 8                                 Da Angela     4.6
# 9                         Taverne da Angelo     4.4
# 10                                  Gandria     4.9
# 11                             Tre Fratelli     4.5
# 12                               Il Tartufo     4.3
# 13                                 Concerto     4.2
# 14                                  Pulcino     3.9
# 15                                  Da Cono     3.9
# 16                                  Azzurro     4.5
# 17                     Cicchetteria Da Rosa     4.5
# 18                                    Conti     4.3
# 19                                    Spiga     4.1
# 20                                   Amalfi     4.3
# 21                                   Cucina     4.2
# 22                              Santa Lucia     4.1
# 23                                Don Leone     4.3
# 24                                   Italia     4.3
# 25                                Il Giglio     4.5
# 26                                    Luca²     4.8
# 27                                  L'altro     4.5
# 28                                   Cinque     4.2
# 29               Riviera Enoteca con Cucina     4.7
# 30                               Tre Cucine     3.8
# 31  Pizzeria Ristorante Molino, Stauffacher     4.1
# 32                                Mamma Mia     3.9
# 33                            Casa Nostrana     4.7
# 34                               Commihalle     4.1
# 35                                Chianalea     4.4
# 36                                Commercio     4.2
# 37                                 Frascati     3.8
# 38                                 Sorrento     4.1
# 39                                Vallocaia     4.0
# 40                                   Latino     4.1
# 41                          Ristorante Totò     3.9
# 42                                Da Biagio     4.4
# 43                                 La Zagra     4.4
# 44                               Il Salotto     4.7
# 45                                   Napoli     3.9
# 46                                 Positano     4.2
# 47                                   Cucina     4.2
# 48                            Bottega Berta     4.3
# 49                                 il Gallo     3.9
# 50                              Casa Ferlin     4.6
# 51                                 Da Guido     3.9
# 52                                  Toscano     4.6
# 53                               La Baracca     4.4
# 54                                  Allegro     4.3
# 55                        Toscano in Puls 5     3.9
# 56                                  Miracle     4.6
# 57                      Antiquario da Marco     4.7
# 58                                 Del Sole     4.1
# 59                                 Paneolio     4.3

# %% [markdown]
# Das ist leider nicht zufriedenstellend, denn offenbar begrenzt sich Google selber. Wir müssen die nexttoken Suche mit einer Suche nach Städten erweitern. Suchen wir "schweizer städte .csv" bei Google.

# %% [markdown]
# ## Ergänzung Schweizer Städte

# %%
t = pd.read_html("https://de.wikipedia.org/wiki/Liste_der_St%C3%A4dte_in_der_Schweiz#St%C3%A4dte_mit_mindestens_10'000_Einwohnern")

# %%
def citynames(elem):
    elem = elem.replace(" 1","").replace(" 2", "").replace(" / 3","")
    return elem
cities = list(t[0][1:][1].apply(citynames))

# %% [markdown]
# ## Jetzt ergänzen wir diese Städte

# %%
new_list = []

url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"
query = "query=italienische+restaurants+in+"
fields = "fields=formatted_address,name,rating,opening_hours,price_level,pagetoken&"
locationbias = "locationbias=point:lat,lng&"
key = "key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&"
pagetoken = ''

for city in cities[:10]: #Nur die ersten Städte
    result = range(4)
    while len(result) > 3: 
    
        print(len(result))
        api_query = url+query+city+"&"+fields+locationbias+key+pagetoken
        print(api_query)
        time.sleep(2)
        r = requests.get(api_query)
        result = r.json()
        print(len(result))
    
        for elem in result['results']:
            address = elem['formatted_address']
            name = elem['name']
            rating = elem['rating']
            lat = elem['geometry']['location']['lat']
            long = elem['geometry']['location']['lng']
    
            mini_dict = {'Addresse': address, 
                     'Name': name,
                     'Rating': rating,
                     'Lat':lat,
                     'Lng':long}
    
            new_list.append(mini_dict)
        
    
        if len(result) > 3:
            pagetoken = 'pagetoken='+result['next_page_token'] 
        else:
            pagetoken = ''
            break
# Out:
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=italienische+restaurants+in+Zürich&fields=formatted_address,name,rating,opening_hours,price_level,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 4
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=italienische+restaurants+in+Zürich&fields=formatted_address,name,rating,opening_hours,price_level,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&pagetoken=CuQD2AEAADgFkaC0lz6QGBiRDaIcRpNx7l1XckgBEYB10H2m1bwZzaOM1-jDvqi3N0Iex_KEbhw1S5WLR7qKThNv9R3gH6N0D4Bk0a9Y7CWMA-vhvDS0XyMJ1XUXcJ1uelTTnWitIKbqj4VJX4gr9t7AxkheXzAu0KGGnklP-x8Su7X7nN57Q36ZyBQh7SjIJwf5g_OWi756NznmPTbbY92SJEO2Egamuk3_vu4u_F-y4xb2HQra5cjpn6-TfY_5clp3pdtD9QAu
QaVfmmBRdAssM309xp1lnEO6DCeslqKKN7d2Adf3M63Q17bAtTZKffL86ETq-NgqtUDBXlTqgflY4ExOHxouVG_eTi11cTxmsdV82UBulLDbsRPvOWDKsqvQFVIBEZVigPIIJGnHxg1QbRnbQVPbTLu_t0qwFWsmiDNKfQoH-ArbVjtO0cZdgwxLsPP2op-wbrEwrsDyRzk4dqEjkeshyMKB6DIrKU3l_tQasLDdLA9F2r8yArU4u_kgqGQTwbL5iPQqJkgd49plNdjOWOni6uC0FvtxyMjJt4YXO22LM9MutrnLx4dBoc_LqGSgObrN1TVLZIa_tMj-aUrLxzVbYs8bCRkn6pxTZk2orBTLafM95qXDxIQWbS7lMWKC0bxX3itHqcT0BoU7jhn56wE0pkEx0Wxfr0cOaxZBAU
# 4
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=italienische+restaurants+in+Lugano&fields=formatted_address,name,rating,opening_hours,price_level,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&pagetoken=CoQFdwIAANKeR1MYlYhFVBKPCBRwrYvCHljqUMt0O1btEQEVHDw5m4CM4KNrUYim59NMi1TU6Ql4n8ySIs_XZ4Ocwb8lOlyNWFUI8P7Zyk9-LCpZYYpOXGqioRbKBBHc4tR6rMJvnuZnrtqdb6Pw4H5fXU-p4GgmP7hgq70ruYfMbMGM9ili8uXmIpoPW52HzkP0VVRnQ_f78YNMLm5lTiZd8FY8SQRnvifn6qfZq5u5ZDBil5g5A_l5oXAnBk80bYdRNeSwmFBFRYGZBXcU4_K9DeI4mLSaBNRnppnB-K_kMgFXxFw7iGtGctfrFckHJ66cbfLPFQnNU3MXOxOKQCDRgJsAdrx23htkjWykAz8vETRbmLdb9rXgXLHkKpocLKD7QH21Lft38lOTkqZRe0tBY0GshC5oezOFt1pyQTE-wwUIDpuqFjPivr2Ya7R5XoTU83IlGz0pU5jylkRowvxx_UHx9jUpHJp3G5NwT6xl2hqZvsieY3qR6JD1y0bIdQ3aF1QCN4Gqc7SBjcENDX7P5gWdhXhxTbWcU7BASky8xdg27SY6oVnw5QRj3YubflHTn3UrnEp8RemvejrRFenywD_lFCuMZz074Z0zjnESfZYxEIwh8DhPi-8LrxiXkCv1dpMhSLvx6MNSK3eOr8J13O_VmCO1ExhQzTDWt623twgkbQvxy-PfNm-GuR5vg6xcUtQV2MvWIVodCoME-acOYtHJWOu3CCBfbwRcqMg8ri6yDTfiE3sA0p8L1bCJRCjhD6p1nl6F2CeTFgK5ihEfjwJRXZWzkddYReWrp-E3FnyDexv9ngnfmA4imMhCVSTvEZaw-uaTZm4krcnMQUF_9QYm2TQSENV05QAki8wHNKBAYuBggFQaFK9fw_6kHzAy9DwwPrOEju_lDUGc
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=italienische+restaurants+in+Biel/Bienne&fields=formatted_address,name,rating,opening_hours,price_level,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3

# %%
df = pd.DataFrame(new_list)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 5 columns):
# Addresse    443 non-null object
# Lat         443 non-null float64
# Lng         443 non-null float64
# Name        443 non-null object
# Rating      443 non-null float64
# dtypes: float64(3), object(2)
# memory usage: 17.4+ KB

# %%
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 443 entries, 0 to 442
# Data columns (total 5 columns):
# Addresse    443 non-null object
# Lat         443 non-null float64
# Lng         443 non-null float64
# Name        443 non-null object
# Rating      443 non-null float64
# dtypes: float64(3), object(2)
# memory usage: 20.8+ KB

# %%
df.to_csv('italrest_allcities.csv')
