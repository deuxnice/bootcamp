# %% [markdown]
# Dies ist meine erster Versuch.

# %% [markdown]
# # 1. Schritt: Daten einlesen

# %%
import pandas as pd
# %matplotlib inline

# %% [markdown]
# felderliste = ['Player', 'PTS', 'FG%', 'TOV%']
#
# so kann man Felder kombinieren, die einen interessieren

# %%
lva_2017_berufe = "LVA_2017_Berufe.csv"

# %%
df = pd.read_csv(lva_2017_berufe)

# %%
df
# Out:
#                                             Unnamed: 0  \
# 0                                                  NaN
# 1                                                  211
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 212
# 14                                                 NaN
# 15                                                 NaN
# ...

# %%
df['LVA-Quote'].max().tail(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     127                 else:
# --> 128                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     129             except Exception:
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/pandas/core/nanops.py in reduction(values, axis, skipna)
#     506         else:
# --> 507             result = getattr(values, meth)(axis)
#     508
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/numpy/core/_methods.py in _amax(a, axis, out, keepdims, initial)
#      27           initial=_NoValue):
# ---> 28     return umr_maximum(a, axis, None, out, keepdims, initial)
#      29
#
# TypeError: '>=' not supported between instances of 'str' and 'float'
#
# ...
